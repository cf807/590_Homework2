# %% [markdown]
# <a href="https://colab.research.google.com/github/cf807/590_Homework2/blob/main/ANLY_590_Homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Christopher Fiaschetti**
#
# ##**ANLY 590**
#
# ##**Homework 2**

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ####**Question 1** - Feedforward: Building a ReLu Neural Network

# %% [markdown]
# Part 1 and 2
#
# View Q1_P1_P2 file in github repo

# %% [markdown]
# Part 3

# %%
def ff_nn_ReLu(x):
    W = np.array([[1,-1,0,1],[0,0,0.5,1]])
    b = np.array([0,0,1,0])
    v = np.array([1,0,-1,1])
    c = np.array([1])

    
    a = np.dot(x,W)+b
    h = tf.nn.relu(a)
    y_a = np.dot(h,v)+c
    y_hat = tf.nn.sigmoid(y_a)
    return y_hat

# %% [markdown]
# Part 4

# %%
# The probabilities are below
x = np.array([[1,0],[0,-1],[0,1]])
print(ff_nn_ReLu(x))
# Out:
# tf.Tensor([0.88079708 0.62245933 0.62245933], shape=(3,), dtype=float64)

# %% [markdown]
# ####**Question 2** - Gradient Descent

# %% [markdown]
# Part 1

# %%
# Load in necessary packages for question
from __future__ import division
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %% [markdown]
# df_dx = -3*x**2 + 100*((2*y**2) -x)*(-1)
#
#
# df_dy = 100*((2*y**2)-x)*(4*y)

# %% [markdown]
# Part 2

# %%
# visualization for the contours of the functions
delta = 1
x = np.arange(-10.0, 10.0, delta)
y = np.arange(-10.0, 10.0, delta)
X, Y = np.meshgrid(x, y)
Z = (3-X**3) + (50 * (2*(Y**2)-X)**2 )
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)

# %% [markdown]
# Part 3

# %%
# gradient function
def grad_f(vector):
    x, y = vector
    df_dx = -3*x**2 + 100*((2*y**2) -x)*(-1)
    df_dy = 100*((2*y**2)-x)*(4*y)
    return np.array([df_dx, df_dy])

# %%
# gradient descent algorithm
def grad_descent(starting_point=None, iterations=10, learning_rate=12):
    if starting_point is None:
        point = np.random.uniform(-10,10,size=2)
    else:
        point = starting_point
    trajectory = [point]
    
    for i in range(iterations):
        grad = grad_f(point)
        point = point - learning_rate * grad
        trajectory.append(point)
        #print(grad)
    return np.array(trajectory)

# %%
grad_f([1,1])
# Out:
# array([-103,  400])

# %%
traj = grad_descent(starting_point = [-1,-1], iterations=10, learning_rate=1)
print(traj)
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# [[                  -1                   -1]
#  [                 302                 1199]
#  [           287763914       -1378802038801]
#  [ -389713152960538922  5073752220772612975]
#  [ 8603526557702505906 -7651528088650440657]
#  [ 2202563723463039294 -7281015212855787217]
#  [ 4959991145024383962  2719744375145487215]
#  [-2843898815244593818 -4319216608837343761]
#  [ 7757335510696192322   234060710732626351]
#  [-8478505451600359346  7757526179080509871]
#  [-5336193571497550102  1341850257797143279]]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in long_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in long_scalars
#   """

# %%
traj = grad_descent(starting_point = [-1,-1], iterations=10, learning_rate=20)
print(traj)
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# [[                  -1                   -1]
#  [                6059                23999]
#  [       2305998580919  -221155189872432001]
#  [-4436284731866935389 -6331286722173537217]
#  [ 5600951482335269103  1802430503844977919]
#  [ -438372203912961765 -7533780852507578689]
#  [-1347404262092590937  3527032548410184063]
#  [-3095262413490761709  8263194076143783231]
#  [-7270181094792949793 -6182362761018586625]
#  [  701871982069162123  1716798158281314239]
#  [-9135827689162247529 -6133714388653488513]]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in long_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in long_scalars
#   """

# %%
traj = grad_descent(starting_point = [-1,-1], iterations=10, learning_rate=.2)
print(traj)
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# [[-1.00000000e+000 -1.00000000e+000]
#  [ 5.96000000e+001  2.39000000e+002]
#  [ 2.28583890e+006 -2.18316725e+009]
#  [ 1.90648773e+020  1.66487260e+030]
#  [ 1.10872031e+062 -7.38351224e+092]
#  [ 2.18065012e+187  6.44034273e+280]
#  [             inf             -inf]
#  [             nan              nan]
#  [             nan              nan]
#  [             nan              nan]
#  [             nan              nan]]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in double_scalars
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# ...

# %% [markdown]
# Part 4

# %%
# gradient descent with momentum algorithm
def grad_descent_with_momentum(starting_point=None, iterations=10, alpha=.9, epsilon=10):
    if starting_point is None:
        point = np.random.uniform(-10,10,size=2)
    else:
        point = starting_point
    
    trajectory = [point]
    v = np.zeros(2)
    
    for i in range(iterations):
        grad = grad_f(point)
        v = alpha * v + epsilon*grad
        point = point - v
        trajectory.append(point)
        
    return np.array(trajectory)

# %%
grad_f([-1,-1])
# Out:
# array([ -303, -1200])

# %%
np.random.seed(10)
traj = grad_descent_with_momentum(starting_point = [-1,-1], iterations=50, epsilon=1, alpha=.9)

fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in double_scalars
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in add
#   del sys.path[0]

# %%
np.random.seed(10)
traj = grad_descent_with_momentum(starting_point = [0,0], iterations=10, epsilon=1, alpha=.9)

fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')

# %%
np.random.seed(10)
traj = grad_descent_with_momentum(starting_point = [0.2,0.2], iterations=10, epsilon=1, alpha=.9)

fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
x= traj[:,0]
y= traj[:,1]
plt.plot(x,y,'-o')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in double_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in double_scalars
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """

# %% [markdown]
# ####**Question 3** Backprop

# %% [markdown]
# Part 1

# %% [markdown]
# derivative of sigmoid function
#
# > sigmoid(x) * (1 - sigmoid(x))
#
# derivative of relu
#
# > 1 if x>0, otherwise 0
#
# derivative of binary cross entropy with respect to y and then y_hat
# > df_dy = log(y_hat) 0 log(1-y_hat)
#
#
# > df_dy_hat = y/y_hat + 1/(1-y_hat) - y/(1-y_hat)

# %% [markdown]
# Part 2

# %%
def grad_f(param_vec, x, y):
    
    W, b, v, c = pack_params(param_vec)
    
    a = np.dot(x,W)+b
    h = relu(a)
    y_a = np.dot(h,v)+c
    y_hat = sigmoid(y_a)
    
    dL_dc = np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a))
    
    dL_dv1 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * h[:,1])
    dL_dv2 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * h[:,0])
    
    dL_db1 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * v[0] * relu_derivative(a[:,0]))
    dL_db2 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * v[1] * relu_derivative(a[:,1]))

    dL_dw11 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * v[0] * relu_derivative(a[:,0]) * x[:,0])
    dL_dw12 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * v[1] * relu_derivative(a[:,1]) * x[:,0])
    dL_dw21 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * v[0] * relu_derivative(a[:,0]) * x[:,1])
    dL_dw22 =  np.average(binary_xent_residual(y, y_hat) * sigmoid_derivative(y_a) * v[1] * relu_derivative(a[:,1]) * x[:,1])
    
    return np.array([dL_dw11, dL_dw12, dL_dw21, dL_dw22, dL_db1, dL_db2, dL_dv1, dL_dv2, dL_dc])

# %% [markdown]
# Part 3

# %%
x = np.random.uniform(low=-2,high=2,size=1000).reshape((500,2))
y=np.zeros(500)
y[np.logical_and(x[:,0]>0 , x[:,1]>0)]=1
y[np.logical_and(x[:,0]<0 , x[:,1]<0)]=1

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %% [markdown]
# Part 4

# %%
def loss(y, y_hat):
    # binary cross entropy
    return  np.sum(- (y*np.log(y_hat) + (1-y)*np.log(1 - y_hat)))

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

def relu(x):
    return np.maximum(x,0)

def relu_derivative(x):
    return np.where(x>0, 1, 0)

def yhat(x, W, b, v, c):
    # returns model prediction 
    h = relu(np.dot(x,W) + b)
    y = sigmoid(np.dot(h,v) + c)
    return y

def binary_xent_residual(y, y_hat):
    return (y/y_hat - (1-y)/(1-y_hat))

def pack_params(param_vec):
    w_11, w_12, w_21, w_22, b_1, b_2, v_1, v_2, c = param_vec
    W = np.array([[w_11,w_12],[w_21,w_22]])
    b = np.array([b_1, b_2])
    v = np.array([v_1,v_2])
    c = np.array([c])
    return((W, b, v, c))

# %%
def grad_descent2(x, y,  iterations=10, learning_rate=1e-2):
    point = np.random.uniform(-.1,.1,size=9).astype("float128")
    trajectory = [point]
    losses = [loss(y, yhat(x, *pack_params(point)))]
    
    for i in range(iterations):
        grad = grad_f(point, x, y)
        point = point + learning_rate * grad
        trajectory.append(point)
        losses.append(loss(y, yhat(x, *pack_params(point))))
    return (np.array(trajectory), losses)

# %%
# gradient descent with momentum algorithm
def grad_descent_with_momentum2(starting_point=None, iterations=10, alpha=.9, epsilon=10):
    point = np.random.uniform(-.1,.1,size=9).astype("float128")
    trajectory = [point]
    losses = [loss(y, yhat(x, *pack_params(point)))]
    v = np.zeros(9)
    for i in range(iterations):
        grad = grad_f(point, x, y)
        v = alpha * v + epsilon*grad
        point = point - v
        trajectory.append(point)
        losses.append(loss(y, yhat(x, *pack_params(point))))
    return (np.array(trajectory), losses)

# %%
traj, losses = grad_descent2(x, y, iterations=5550,learning_rate=1e-2)
plt.plot(losses)

# %%
traj, losses = grad_descent2(x, y, iterations=20050,learning_rate=1e-2)
plt.plot(losses)

# %% [markdown]
# More iterations most certainly helped the gradient descent

# %% [markdown]
# Part 5

# %%
traj, losses =  grad_descent_with_momentum2(iterations=50, epsilon=23, alpha=.25)
plt.plot(losses)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in multiply
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in multiply
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %% [markdown]
# Trouble with implementation has lead to gradient descent with momentum to not be as efficient as intended. However, given the nature of gradient descent with momentum, one would expect it to perform better than regular gradient descent.

# %% [markdown]
# Part 6

# %%
delta = 0.025
x1 = np.arange(-2.0, 2.0, delta)
x2 = np.arange(-2.0, 2.0, delta)
X1, X2 = np.meshgrid(x1, x2)
YHAT = yhat(np.array((X1.ravel(),X2.ravel())).T, *pack_params(traj[-1])).reshape((160,160))
fig, ax = plt.subplots()
CS = ax.contourf(X1, X2, YHAT)

plt.scatter(x[:,0],x[:,1],c=y)
